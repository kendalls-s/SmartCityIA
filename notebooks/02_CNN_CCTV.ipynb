# %% [markdown]
# # Asistente Inteligente para Seguridad Urbana en Costa Rica
# ### Módulos del Asistente Inteligente — CNN Detección en imágenes
# ### Módulo 1: Detección de actividad sospechosa en imágenes CCTV
# ### Integrantes :
# ### Profesor:

# %%
import pandas as pd
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from CNN import procesar_lote_videos_split
print("✅ Funciona")
# Out:
# ✅ Funciona

# %% [markdown]
# ## 1.Importación de librerias

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread

# %% [markdown]
# ## 2.Importación de fuentes de datos

# %%
#Fotogramas videos carpeta "Normal-Videos-Part-1"
procesar_lote_videos_split(
    ruta_carpeta=r"data\raw\Normal-Videos-Part-1",
    carpeta_base_destino="Normal",  # El nombre de la clase
    limite_videos=50,
    cada_n_frames=30)
# Out:
# Buscando videos en: C:\SmartCityIA\data\raw\Normal-Videos-Part-1
#  -> TRAIN: Normal_Videos_003_x264 (94 fotos)
#  -> TRAIN: Normal_Videos_006_x264 (14 fotos)
#  -> TRAIN: Normal_Videos_010_x264 (35 fotos)
#  -> TRAIN: Normal_Videos_014_x264 (49 fotos)
#  -> TRAIN: Normal_Videos_015_x264 (15 fotos)
#  -> TRAIN: Normal_Videos_018_x264 (39 fotos)
#  -> TRAIN: Normal_Videos_019_x264 (94 fotos)
#  -> TRAIN: Normal_Videos_024_x264 (35 fotos)
#  -> TRAIN: Normal_Videos_025_x264 (20 fotos)
#  -> TRAIN: Normal_Videos_027_x264 (164 fotos)
#  -> TRAIN: Normal_Videos_033_x264 (55 fotos)
#  -> TRAIN: Normal_Videos_034_x264 (43 fotos)
#  -> TRAIN: Normal_Videos_041_x264 (42 fotos)
#  -> TRAIN: Normal_Videos_042_x264 (105 fotos)
#  -> TRAIN: Normal_Videos_048_x264 (54 fotos)
#  -> TRAIN: Normal_Videos_050_x264 (139 fotos)
#  -> TRAIN: Normal_Videos_051_x264 (78 fotos)
#  -> TRAIN: Normal_Videos_056_x264 (52 fotos)
#  -> TRAIN: Normal_Videos_059_x264 (61 fotos)
#  -> TRAIN: Normal_Videos_063_x264 (11 fotos)
#  -> TRAIN: Normal_Videos_067_x264 (35 fotos)
#  -> TRAIN: Normal_Videos_070_x264 (33 fotos)
#  -> TRAIN: Normal_Videos_100_x264 (20 fotos)
#  -> TRAIN: Normal_Videos_129_x264 (15 fotos)
#  -> TRAIN: Normal_Videos_150_x264 (28 fotos)
#  -> TRAIN: Normal_Videos_168_x264 (57 fotos)
#  -> TRAIN: Normal_Videos_175_x264 (294 fotos)
#  -> TRAIN: Normal_Videos_182_x264 (136 fotos)
#  -> TRAIN: Normal_Videos_189_x264 (24 fotos)
#  -> TRAIN: Normal_Videos_196_x264 (66 fotos)
#  -> TRAIN: Normal_Videos_203_x264 (85 fotos)
#  -> TRAIN: Normal_Videos_210_x264 (180 fotos)
#  -> TRAIN: Normal_Videos_217_x264 (60 fotos)
#  -> TRAIN: Normal_Videos_224_x264 (231 fotos)
#  -> TRAIN: Normal_Videos_246_x264 (166 fotos)
#  -> TRAIN: Normal_Videos_247_x264 (273 fotos)
#  -> TRAIN: Normal_Videos_248_x264 (37 fotos)
#  -> TRAIN: Normal_Videos_251_x264 (13 fotos)
#  -> TRAIN: Normal_Videos_289_x264 (28 fotos)
#  -> TRAIN: Normal_Videos_310_x264 (83 fotos)
#  -> TEST: Normal_Videos_312_x264 (42 fotos)
#  -> TEST: Normal_Videos_317_x264 (30 fotos)
#  -> TEST: Normal_Videos_345_x264 (6 fotos)
#  -> TEST: Normal_Videos_352_x264 (180 fotos)
#  -> TEST: Normal_Videos_360_x264 (32 fotos)
#  -> TEST: Normal_Videos_365_x264 (220 fotos)
#  -> TEST: Normal_Videos_401_x264 (54 fotos)
#  -> TEST: Normal_Videos_417_x264 (35 fotos)
#  -> TEST: Normal_Videos_439_x264 (140 fotos)
#  -> TEST: Normal_Videos_452_x264 (14 fotos)

# %%
#Fotogramas videos carpeta "Fighting"
procesar_lote_videos_split(
    ruta_carpeta=r"data\raw\Fighting",
    carpeta_base_destino="Pelea",  # El nombre de la clase
    limite_videos=50,
    cada_n_frames=30)
# Out:
# Buscando videos en: C:\SmartCityIA\data\raw\Fighting
#  -> TRAIN: Fighting002_x264 (89 fotos)
#  -> TRAIN: Fighting003_x264 (103 fotos)
#  -> TRAIN: Fighting004_x264 (559 fotos)
#  -> TRAIN: Fighting005_x264 (59 fotos)
#  -> TRAIN: Fighting006_x264 (31 fotos)
#  -> TRAIN: Fighting007_x264 (126 fotos)
#  -> TRAIN: Fighting008_x264 (437 fotos)
#  -> TRAIN: Fighting009_x264 (71 fotos)
#  -> TRAIN: Fighting010_x264 (195 fotos)
#  -> TRAIN: Fighting011_x264 (274 fotos)
#  -> TRAIN: Fighting012_x264 (38 fotos)
#  -> TRAIN: Fighting013_x264 (47 fotos)
#  -> TRAIN: Fighting014_x264 (156 fotos)
#  -> TRAIN: Fighting015_x264 (330 fotos)
#  -> TRAIN: Fighting016_x264 (96 fotos)
#  -> TRAIN: Fighting017_x264 (69 fotos)
#  -> TRAIN: Fighting018_x264 (46 fotos)
#  -> TRAIN: Fighting019_x264 (107 fotos)
#  -> TRAIN: Fighting020_x264 (73 fotos)
#  -> TRAIN: Fighting021_x264 (118 fotos)
#  -> TRAIN: Fighting022_x264 (145 fotos)
#  -> TRAIN: Fighting023_x264 (34 fotos)
#  -> TRAIN: Fighting024_x264 (218 fotos)
#  -> TRAIN: Fighting025_x264 (159 fotos)
#  -> TRAIN: Fighting026_x264 (116 fotos)
#  -> TRAIN: Fighting027_x264 (128 fotos)
#  -> TRAIN: Fighting028_x264 (80 fotos)
#  -> TRAIN: Fighting029_x264 (145 fotos)
#  -> TRAIN: Fighting030_x264 (74 fotos)
#  -> TRAIN: Fighting031_x264 (300 fotos)
#  -> TRAIN: Fighting032_x264 (44 fotos)
#  -> TRAIN: Fighting033_x264 (36 fotos)
#  -> TRAIN: Fighting034_x264 (208 fotos)
#  -> TRAIN: Fighting035_x264 (32 fotos)
#  -> TRAIN: Fighting036_x264 (125 fotos)
#  -> TRAIN: Fighting037_x264 (145 fotos)
#  -> TRAIN: Fighting038_x264 (26 fotos)
#  -> TRAIN: Fighting039_x264 (227 fotos)
#  -> TRAIN: Fighting040_x264 (77 fotos)
#  -> TRAIN: Fighting041_x264 (1054 fotos)
#  -> TEST: Fighting042_x264 (74 fotos)
#  -> TEST: Fighting043_x264 (104 fotos)
#  -> TEST: Fighting044_x264 (209 fotos)
#  -> TEST: Fighting045_x264 (197 fotos)
#  -> TEST: Fighting046_x264 (99 fotos)
#  -> TEST: Fighting047_x264 (148 fotos)
#  -> TEST: Fighting048_x264 (229 fotos)
#  -> TEST: Fighting049_x264 (51 fotos)
#  -> TEST: Fighting050_x264 (875 fotos)
#  -> TEST: Fighting051_x264 (220 fotos)

# %%
#Fotogramas videos carpeta "Arson"
procesar_lote_videos_split(
    ruta_carpeta=r"data\raw\Arson",
    carpeta_base_destino="Vandalismo",  # El nombre de la clase
    limite_videos=50,
    cada_n_frames=30)
# Out:
# Buscando videos en: C:\SmartCityIA\data\raw\Arson
#  -> TRAIN: Arson001_x264 (139 fotos)
#  -> TRAIN: Arson002_x264 (147 fotos)
#  -> TRAIN: Arson003_x264 (133 fotos)
#  -> TRAIN: Arson005_x264 (39 fotos)
#  -> TRAIN: Arson006_x264 (93 fotos)
#  -> TRAIN: Arson007_x264 (208 fotos)
#  -> TRAIN: Arson008_x264 (40 fotos)
#  -> TRAIN: Arson009_x264 (24 fotos)
#  -> TRAIN: Arson010_x264 (105 fotos)
#  -> TRAIN: Arson011_x264 (42 fotos)
#  -> TRAIN: Arson012_x264 (29 fotos)
#  -> TRAIN: Arson013_x264 (212 fotos)
#  -> TRAIN: Arson014_x264 (87 fotos)
#  -> TRAIN: Arson015_x264 (340 fotos)
#  -> TRAIN: Arson016_x264 (59 fotos)
#  -> TRAIN: Arson017_x264 (46 fotos)
#  -> TRAIN: Arson018_x264 (28 fotos)
#  -> TRAIN: Arson019_x264 (4218 fotos)
#  -> TRAIN: Arson020_x264 (80 fotos)
#  -> TRAIN: Arson021_x264 (48 fotos)
#  -> TRAIN: Arson022_x264 (287 fotos)
#  -> TRAIN: Arson023_x264 (45 fotos)
#  -> TRAIN: Arson024_x264 (112 fotos)
#  -> TRAIN: Arson025_x264 (176 fotos)
#  -> TRAIN: Arson026_x264 (196 fotos)
#  -> TRAIN: Arson027_x264 (89 fotos)
#  -> TRAIN: Arson028_x264 (80 fotos)
#  -> TRAIN: Arson029_x264 (44 fotos)
#  -> TRAIN: Arson030_x264 (168 fotos)
#  -> TRAIN: Arson031_x264 (96 fotos)
#  -> TRAIN: Arson032_x264 (92 fotos)
#  -> TRAIN: Arson034_x264 (79 fotos)
#  -> TRAIN: Arson035_x264 (47 fotos)
#  -> TRAIN: Arson036_x264 (56 fotos)
#  -> TRAIN: Arson037_x264 (26 fotos)
#  -> TRAIN: Arson038_x264 (24 fotos)
#  -> TRAIN: Arson039_x264 (112 fotos)
#  -> TRAIN: Arson040_x264 (94 fotos)
#  -> TRAIN: Arson041_x264 (125 fotos)
#  -> TRAIN: Arson042_x264 (195 fotos)
#  -> TEST: Arson044_x264 (39 fotos)
#  -> TEST: Arson045_x264 (125 fotos)
#  -> TEST: Arson046_x264 (69 fotos)
#  -> TEST: Arson047_x264 (48 fotos)
#  -> TEST: Arson048_x264 (13 fotos)
#  -> TEST: Arson049_x264 (12 fotos)
#  -> TEST: Arson050_x264 (52 fotos)
#  -> TEST: Arson051_x264 (35 fotos)
#  -> TEST: Arson052_x264 (158 fotos)
#  -> TEST: Arson053_x264 (225 fotos)

# %%
ruta = r"..\data\processed\test\Vandalismo"
total_fotos = len(os.listdir(ruta))

print(f"Hay {total_fotos} fotos en la carpeta de Vandalismo")
# Out:
# Hay 776 fotos en la carpeta de Vandalismo

# %%
#Fotogramas videos carpeta "Assault"
procesar_lote_videos_split(
    ruta_carpeta=r"data\raw\Assault",
    carpeta_base_destino="Asaltos",  # El nombre de la clase
    limite_videos=50,
    cada_n_frames=30)
# Out:
# Buscando videos en: C:\SmartCityIA\data\raw\Assault
#  -> TRAIN: Assault001_x264 (82 fotos)
#  -> TRAIN: Assault002_x264 (84 fotos)
#  -> TRAIN: Assault003_x264 (148 fotos)
#  -> TRAIN: Assault004_x264 (107 fotos)
#  -> TRAIN: Assault005_x264 (40 fotos)
#  -> TRAIN: Assault006_x264 (269 fotos)
#  -> TRAIN: Assault007_x264 (65 fotos)
#  -> TRAIN: Assault008_x264 (251 fotos)
#  -> TRAIN: Assault009_x264 (119 fotos)
#  -> TRAIN: Assault010_x264 (539 fotos)
#  -> TRAIN: Assault011_x264 (76 fotos)
#  -> TRAIN: Assault012_x264 (26 fotos)
#  -> TRAIN: Assault013_x264 (79 fotos)
#  -> TRAIN: Assault014_x264 (63 fotos)
#  -> TRAIN: Assault015_x264 (49 fotos)
#  -> TRAIN: Assault016_x264 (220 fotos)
#  -> TRAIN: Assault017_x264 (81 fotos)
#  -> TRAIN: Assault018_x264 (12 fotos)
#  -> TRAIN: Assault019_x264 (84 fotos)
#  -> TRAIN: Assault020_x264 (15 fotos)
#  -> TRAIN: Assault022_x264 (83 fotos)
#  -> TRAIN: Assault023_x264 (33 fotos)
#  -> TRAIN: Assault024_x264 (14 fotos)
#  -> TRAIN: Assault025_x264 (38 fotos)
#  -> TRAIN: Assault026_x264 (28 fotos)
#  -> TRAIN: Assault027_x264 (231 fotos)
#  -> TRAIN: Assault028_x264 (87 fotos)
#  -> TRAIN: Assault029_x264 (20 fotos)
#  -> TRAIN: Assault030_x264 (58 fotos)
#  -> TRAIN: Assault031_x264 (25 fotos)
#  -> TRAIN: Assault032_x264 (19 fotos)
#  -> TRAIN: Assault033_x264 (42 fotos)
#  -> TRAIN: Assault034_x264 (77 fotos)
#  -> TRAIN: Assault035_x264 (29 fotos)
#  -> TRAIN: Assault036_x264 (30 fotos)
#  -> TRAIN: Assault037_x264 (106 fotos)
#  -> TRAIN: Assault038_x264 (4 fotos)
#  -> TRAIN: Assault039_x264 (9 fotos)
#  -> TRAIN: Assault040_x264 (125 fotos)
#  -> TRAIN: Assault041_x264 (167 fotos)
#  -> TEST: Assault042_x264 (299 fotos)
#  -> TEST: Assault044_x264 (25 fotos)
#  -> TEST: Assault045_x264 (37 fotos)
#  -> TEST: Assault046_x264 (31 fotos)
#  -> TEST: Assault047_x264 (111 fotos)
#  -> TEST: Assault048_x264 (60 fotos)
#  -> TEST: Assault049_x264 (44 fotos)
#  -> TEST: Assault050_x264 (20 fotos)
#  -> TEST: Assault051_x264 (20 fotos)
#  -> TEST: Assault052_x264 (26 fotos)

# %%
ruta = r"../data\processed\test\Asaltos"
total_fotos = len(os.listdir(ruta))

print(f"Hay {total_fotos} fotos en la carpeta Asaltos")
# Out:
# Hay 673 fotos en la carpeta Asaltos

# %%
train_path = "../data/processed/train"
test_path = "../data/processed/test"

# %%
os.listdir(train_path)
# Out:
# ['Asaltos', 'Normal', 'Pelea', 'Vandalismo']

# %%
os.listdir(test_path)
# Out:
# ['Asaltos', 'Normal', 'Pelea', 'Vandalismo']

# %% [markdown]
# # 3.Preprocesado

# %% [markdown]
# ## 3.1Visualización de imágenes

# %%
os.listdir(train_path + '/Asaltos')[0]
# Out:
# 'Assault001_x264_f1020.jpg'

# %%
ruta_Asalto= train_path + '/Asaltos/' + os.listdir(train_path + '/Asaltos')[300] # os.listdir() crea una lista en este caso lista de las imagenes

# %%
imagen_Asalto= imread(ruta_Asalto)# imread() Su trabajo es abrir el archivo de imagen que se encuentra en la ruta especificada y "traducirlo".

# %%
plt.imshow(imagen_Asalto) #Mostrar la imagen

# %% [markdown]
# **Cantidad imágenes en la carpeta de entrenamiento**

# %%
len(os.listdir(train_path+'\\Normal'))
# Out:
# 3063

# %%
len(os.listdir(train_path+'\\Asaltos'))
# Out:
# 3634

# %%
len(os.listdir(train_path+'\\Pelea'))
# Out:
# 6397

# %%
len(os.listdir(train_path+'\\Vandalismo'))
# Out:
# 8260

# %% [markdown]
# ## 3.2 Calcular dimensiones promedio

# %%
dim1_ddl = []
dim2_ddl = []
for fichero_imagen in os.listdir(train_path+'\\Normal'): #lista de todas las imagenes de la carpeta dandelion
    img = imread(train_path+'\\Normal'+'\\'+fichero_imagen) #Las "traduce"
    d1,d2,colors = img.shape #(Altura, Anchura, Canales)
    dim1_ddl.append(d1)
    dim2_ddl.append(d2)

# %%
sns.jointplot(x=dim1_ddl,y=dim2_ddl)

# %%
dim1_ddl = []
dim2_ddl = []
for fichero_imagen in os.listdir(train_path+'\\Asaltos'): #lista de todas las imagenes de la carpeta dandelion
    img = imread(train_path+'\\Asaltos'+'\\'+fichero_imagen) #Las "traduce"
    d1,d2,colors = img.shape #(Altura, Anchura, Canales)
    dim1_ddl.append(d1)
    dim2_ddl.append(d2)

# %%
sns.jointplot(x=dim1_ddl,y=dim2_ddl)

# %%
dim1_ddl = []
dim2_ddl = []
for fichero_imagen in os.listdir(train_path+'\\Pelea'): #lista de todas las imagenes de la carpeta dandelion
    img = imread(train_path+'\\Pelea'+'\\'+fichero_imagen) #Las "traduce"
    d1,d2,colors = img.shape #(Altura, Anchura, Canales)
    dim1_ddl.append(d1)
    dim2_ddl.append(d2)

# %%
sns.jointplot(x=dim1_ddl,y=dim2_ddl)

# %%
dim1_ddl = []
dim2_ddl = []
for fichero_imagen in os.listdir(train_path+'\\Vandalismo'): #lista de todas las imagenes de la carpeta dandelion
    img = imread(train_path+'\\Vandalismo'+'\\'+fichero_imagen) #Las "traduce"
    d1,d2,colors = img.shape #(Altura, Anchura, Canales)
    dim1_ddl.append(d1)
    dim2_ddl.append(d2)

# %%
sns.jointplot(x=dim1_ddl,y=dim2_ddl)

# %% [markdown]
# # 3.3 Manipulación de imágenes

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=20, # rotación máxima de 20º (depende del caso de uso)
                               width_shift_range=0.10, # Desplazamiento en la anchura máximo del -5% --- +5%
                               height_shift_range=0.10, # Desplazamiento en la altura máximo del -5% --- +5%
                               rescale=1/255, # Reescalar la imagen para normalizarla entre 0-1
                               shear_range=0.1, # Distorsión de la imagen a partir de un eje - persepectiva (max 10%)
                               zoom_range=0.1, # Zoom in máximo 10%
                               horizontal_flip=True, # Permitir giro horizontal de la imagen (espejo)
                               fill_mode='nearest' # Rellenar píxeles vacíos con el valor más cercano
                              )

# %%
plt.imshow(imagen_Asalto)

# %%
plt.imshow(image_gen.random_transform(imagen_Asalto)) # random_transform, Crea variaciones infinitas de las imágenes originales.

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 21354 images belonging to 4 classes.

# %%
image_gen.flow_from_directory(test_path)
# Out:
# Found 4408 images belonging to 4 classes.

# %%
batch_size = 16 #Definimos un batch_size en función de la RAM

# %%
image_shape = (240,320,3)

# %%
train_image_gen = image_gen.flow_from_directory(train_path,
                                               target_size=image_shape[:2], #image_shape = (240,320,3), target_size solo necesita anchura x altura
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='categorical') #binary si clasificación binaria
# Out:
# Found 21354 images belonging to 4 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_path,
                                               target_size=image_shape[:2], # image_shape = (250,335) no interesa el canal 3
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='categorical',shuffle=False) #En el conjunto de test no aplicamos shuffle para no "barajar" las imágenes
# Out:
# Found 4408 images belonging to 4 classes.

# %%
train_image_gen.class_indices
# Out:
# {'Asaltos': 0, 'Normal': 1, 'Pelea': 2, 'Vandalismo': 3}

# %% [markdown]
# # 4.Creación del Modelo

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %%
model = Sequential()

# CAPA CONVOLUCIONAL
model.add(Conv2D(filters=32, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

# CAPA CONVOLUCIONAL (más capas convolucionales conforme mayor complejidad del dataset de imágenes, aumentar progresivamente número de filtros en potencia de 2)
model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

# CAPA CONVOLUCIONAL (más capas convolucionales conforme mayor complejidad del dataset de imágenes, aumentar progresivamente número de filtros en potencia de 2)
model.add(Conv2D(filters=128, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

# CAPA FLATTEN: Convierte las imágenes de 250x335 en un array de 1 dimensión de 250x335 = 83750 valores antes de la capa final
model.add(Flatten())

# CAPA DENSE (Indicar neuronas potencia de 2, variable para optimizar modelo)
model.add(Dense(256))
model.add(Activation('relu'))

# CAPA DROPOUT (ayuda a reducir overfitting desactivando aleatoriamente neuronas durante el entrenamiento(epoc))
model.add(Dropout(0.5))

# CAPA FINAL DE CLASIFICACIÓN (5 posibles clases = 5 neuronas, si fuera problema binario utilizar 'sigmoid' y 1 neurona)
model.add(Dense(4, activation='softmax'))


model.compile(loss='categorical_crossentropy', #binary_crossentropy si fuera binario
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 238, 318, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 119, 159, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 117, 157, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 58, 78, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 56, 76, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 28, 38, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 136192)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │    34,865,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,959,684 (133.36 MB)
#  Trainable params: 34,959,684 (133.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 5.Entrenamiento del modelo

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=2)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
results = model.fit(train_image_gen,
                              epochs=5,
                              validation_data=test_image_gen,
                              callbacks=[early_stop])
# Out:
# Epoch 1/5
# 1335/1335 ━━━━━━━━━━━━━━━━━━━━ 2119s 2s/step - accuracy: 0.6806 - loss: 0.7662 - val_accuracy: 0.4723 - val_loss: 2.0609
# Epoch 2/5
# 1335/1335 ━━━━━━━━━━━━━━━━━━━━ 2102s 2s/step - accuracy: 0.8385 - loss: 0.4353 - val_accuracy: 0.4784 - val_loss: 2.3794
# Epoch 3/5
# 1335/1335 ━━━━━━━━━━━━━━━━━━━━ 2070s 2s/step - accuracy: 0.8886 - loss: 0.3108 - val_accuracy: 0.5245 - val_loss: 2.4803

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses[['loss','val_loss']].plot()
# Out:
# <Axes: >

# %%
losses[['accuracy','val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # 6. Evaluación del modelo

# %% [markdown]
# ## 6.1 Predicción sobre el conjunto de Test

# %%
model.metrics_names
# Out:
# ['loss', 'compile_metrics']

# %%
pred_probabilities = model.predict(test_image_gen)
# Out:
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 121s 437ms/step

# %%
pred_probabilities #Probabilidad
# Out:
# array([[6.6240376e-01, 7.0852758e-03, 3.2633111e-01, 4.1798260e-03],
#        [9.4844961e-01, 4.2175848e-04, 3.6664680e-02, 1.4464060e-02],
#        [8.4531069e-02, 5.4776944e-02, 8.0377442e-01, 5.6917589e-02],
#        ...,
#        [8.4209851e-06, 2.4093634e-07, 3.3061968e-03, 9.9668509e-01],
#        [5.9051992e-04, 1.5919133e-05, 3.9165407e-02, 9.6022815e-01],
#        [6.5297895e-06, 1.0260102e-07, 2.1064745e-01, 7.8934592e-01]],
#       shape=(4408, 4), dtype=float32)

# %%
test_image_gen.classes #Respuestas correctas
# Out:
# array([0, 0, 0, ..., 3, 3, 3], shape=(4408,), dtype=int32)

# %%
# predictions = model.predict_classes(test_image_gen)
#Usar si la sale predict_classes como deprecated:
predictions = np.argmax(model.predict(test_image_gen), axis=-1)
# Out:
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 133s 483ms/step

# %%
predictions
# Out:
# array([0, 0, 2, ..., 3, 3, 2], shape=(4408,))

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(test_image_gen.classes,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.22      0.29      0.25       673
#            1       0.67      0.80      0.73       753
#            2       0.74      0.40      0.52      2206
#            3       0.44      0.82      0.57       776
#
#     accuracy                           0.52      4408
#    macro avg       0.52      0.57      0.52      4408
# weighted avg       0.60      0.52      0.52      4408
