# %% [markdown]
# # Asistente Inteligente para Seguridad Urbana en Costa Rica
# ### Módulos del Asistente Inteligente — CNN Detección en imágenes
# ### Módulo 1: Detección de actividad sospechosa en imágenes CCTV
# ### Integrantes :
# ### Profesor:

# %%
import pandas as pd
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from CNN import procesar_lote_videos_split, vaciar_contenido
print("Funciona")
# Out:
# Funciona

# %%
vaciar_contenido()
# Out:
# Contenido eliminado de: train/Normal
# Contenido eliminado de: train/Asaltos
# Contenido eliminado de: train/Pelea
# Contenido eliminado de: train/Vandalismo
# Contenido eliminado de: test/Normal
# Contenido eliminado de: test/Asaltos
# Contenido eliminado de: test/Pelea
# Contenido eliminado de: test/Vandalismo

# %% [markdown]
# ## 1.Importación de librerias

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread

# %% [markdown]
# ## 2.Importación de fuentes de datos

# %%
ruta = r"..\data\raw\Normal-Videos-Part-1"
total_fotos = len(os.listdir(ruta))

print(f"Hay {total_fotos} videos en la carpeta ")
# Out:
# Hay 150 videos en la carpeta

# %%
ruta = r"..\data\raw\Fighting"
total_fotos = len(os.listdir(ruta))

print(f"Hay {total_fotos} videos en la carpeta ")
# Out:
# Hay 50 videos en la carpeta

# %%
ruta = r"..\data\raw\Assault"
total_fotos = len(os.listdir(ruta))

print(f"Hay {total_fotos} videos en la carpeta ")
# Out:
# Hay 50 videos en la carpeta

# %%
ruta = r"..\data\raw\Arson"
total_fotos = len(os.listdir(ruta))

print(f"Hay {total_fotos} videos en la carpeta ")
# Out:
# Hay 50 videos en la carpeta

# %%
ruta = r"..\data\raw\Vandalism"
total_fotos = len(os.listdir(ruta))

print(f"Hay {total_fotos} videos en la carpeta ")
# Out:
# Hay 50 videos en la carpeta

# %%
ruta = r"..\data\raw\Stealing"
total_fotos = len(os.listdir(ruta))

print(f"Hay {total_fotos} videos en la carpeta ")
# Out:
# Hay 100 videos en la carpeta

# %%
#Fotogramas videos carpeta "Normal-Videos-Part-1"
procesar_lote_videos_split(
    ruta_carpeta="data/raw/Normal-Videos-Part-1",
    carpeta_base_destino="Normal",
    limite_videos=150,
    cada_n_frames=30,
    umbral=1.2,
    max_fotos_video=40)
# Out:
#  -> TRAIN: Normal_Videos_003_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_006_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_010_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_014_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_015_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_018_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_019_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_024_x264 (9 fotos)
#  -> TRAIN: Normal_Videos_025_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_027_x264 (4 fotos)
#  -> TRAIN: Normal_Videos_033_x264 (22 fotos)
#  -> TRAIN: Normal_Videos_034_x264 (5 fotos)
#  -> TRAIN: Normal_Videos_041_x264 (31 fotos)
#  -> TRAIN: Normal_Videos_042_x264 (29 fotos)
#  -> TRAIN: Normal_Videos_048_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_050_x264 (40 fotos)
#  -> TRAIN: Normal_Videos_051_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_056_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_059_x264 (26 fotos)
#  -> TRAIN: Normal_Videos_063_x264 (1 fotos)
#  -> TRAIN: Normal_Videos_067_x264 (3 fotos)
#  -> TRAIN: Normal_Videos_070_x264 (1 fotos)
#  -> TRAIN: Normal_Videos_100_x264 (2 fotos)
#  -> TRAIN: Normal_Videos_129_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_150_x264 (14 fotos)
#  -> TRAIN: Normal_Videos_168_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_175_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_182_x264 (10 fotos)
#  -> TRAIN: Normal_Videos_189_x264 (18 fotos)
#  -> TRAIN: Normal_Videos_196_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_203_x264 (3 fotos)
#  -> TRAIN: Normal_Videos_210_x264 (19 fotos)
#  -> TRAIN: Normal_Videos_217_x264 (3 fotos)
#  -> TRAIN: Normal_Videos_224_x264 (1 fotos)
#  -> TRAIN: Normal_Videos_246_x264 (12 fotos)
#  -> TRAIN: Normal_Videos_247_x264 (2 fotos)
#  -> TRAIN: Normal_Videos_248_x264 (4 fotos)
#  -> TRAIN: Normal_Videos_251_x264 (5 fotos)
#  -> TRAIN: Normal_Videos_289_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_310_x264 (34 fotos)
#  -> TRAIN: Normal_Videos_312_x264 (1 fotos)
#  -> TRAIN: Normal_Videos_317_x264 (2 fotos)
#  -> TRAIN: Normal_Videos_345_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_352_x264 (1 fotos)
#  -> TRAIN: Normal_Videos_360_x264 (11 fotos)
#  -> TRAIN: Normal_Videos_365_x264 (5 fotos)
#  -> TRAIN: Normal_Videos_401_x264 (3 fotos)
#  -> TRAIN: Normal_Videos_417_x264 (22 fotos)
#  -> TRAIN: Normal_Videos_439_x264 (3 fotos)
#  -> TRAIN: Normal_Videos_452_x264 (11 fotos)
#  -> TRAIN: Normal_Videos_453_x264 (2 fotos)
#  -> TRAIN: Normal_Videos_478_x264 (40 fotos)
#  -> TRAIN: Normal_Videos_576_x264 (40 fotos)
#  -> TRAIN: Normal_Videos_597_x264 (1 fotos)
#  -> TRAIN: Normal_Videos_603_x264 (14 fotos)
#  -> TRAIN: Normal_Videos_606_x264 (4 fotos)
#  -> TRAIN: Normal_Videos_621_x264 (9 fotos)
#  -> TRAIN: Normal_Videos_634_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_641_x264 (27 fotos)
#  -> TRAIN: Normal_Videos_656_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_686_x264 (3 fotos)
#  -> TRAIN: Normal_Videos
  # El nombre de la clase
    limite_videos=50,
    cada_n_frames=30,
    umbral=0.6,
    max_fotos_video=50)
# Out:
#  -> TRAIN: Arson001_x264 (11 fotos)
#  -> TRAIN: Arson002_x264 (40 fotos)
#  -> TRAIN: Arson003_x264 (50 fotos)
#  -> TRAIN: Arson005_x264 (22 fotos)
#  -> TRAIN: Arson006_x264 (31 fotos)
#  -> TRAIN: Arson007_x264 (3 fotos)
#  -> TRAIN: Arson008_x264 (22 fotos)
#  -> TRAIN: Arson009_x264 (24 fotos)
#  -> TRAIN: Arson010_x264 (16 fotos)
#  -> TRAIN: Arson011_x264 (40 fotos)
#  -> TRAIN: Arson012_x264 (13 fotos)
#  -> TRAIN: Arson013_x264 (12 fotos)
#  -> TRAIN: Arson014_x264 (17 fotos)
#  -> TRAIN: Arson015_x264 (50 fotos)
#  -> TRAIN: Arson016_x264 (26 fotos)
#  -> TRAIN: Arson017_x264 (6 fotos)
#  -> TRAIN: Arson018_x264 (11 fotos)
#  -> TRAIN: Arson019_x264 (50 fotos)
#  -> TRAIN: Arson020_x264 (17 fotos)
#  -> TRAIN: Arson021_x264 (5 fotos)
#  -> TRAIN: Arson022_x264 (24 fotos)
#  -> TRAIN: Arson023_x264 (25 fotos)
#  -> TRAIN: Arson024_x264 (50 fotos)
#  -> TRAIN: Arson025_x264 (49 fotos)
#  -> TRAIN: Arson026_x264 (50 fotos)
#  -> TRAIN: Arson027_x264 (35 fotos)
#  -> TRAIN: Arson028_x264 (34 fotos)
#  -> TRAIN: Arson029_x264 (8 fotos)
#  -> TRAIN: Arson030_x264 (11 fotos)
#  -> TRAIN: Arson031_x264 (24 fotos)
#  -> TRAIN: Arson032_x264 (50 fotos)
#  -> TRAIN: Arson034_x264 (19 fotos)
#  -> TRAIN: Arson035_x264 (38 fotos)
#  -> TRAIN: Arson036_x264 (11 fotos)
#  -> TRAIN: Arson037_x264 (25 fotos)
#  -> TRAIN: Arson038_x264 (22 fotos)
#  -> TRAIN: Arson039_x264 (50 fotos)
#  -> TRAIN: Arson040_x264 (20 fotos)
#  -> TRAIN: Arson041_x264 (50 fotos)
#  -> TRAIN: Arson042_x264 (50 fotos)
#  -> TEST: Arson044_x264 (0 fotos)
#  -> TEST: Arson045_x264 (16 fotos)
#  -> TEST: Arson046_x264 (4 fotos)
#  -> TEST: Arson047_x264 (35 fotos)
#  -> TEST: Arson048_x264 (4 fotos)
#  -> TEST: Arson049_x264 (8 fotos)
#  -> TEST: Arson050_x264 (35 fotos)
#  -> TEST: Arson051_x264 (26 fotos)
#  -> TEST: Arson052_x264 (49 fotos)
#  -> TEST: Arson053_x264 (50 fotos)

# %%
#Fotogramas videos carpeta "Assault"
procesar_lote_videos_split(
    ruta_carpeta=r"data\raw\Assault",
    carpeta_base_destino="Asaltos",  # El nombre de la clase
    limite_videos=50,
    cada_n_frames=30,
    umbral=0.5,
    max_fotos_video=50)
# Out:
#  -> TRAIN: Assault001_x264 (50 fotos)
#  -> TRAIN: Assault002_x264 (50 fotos)
#  -> TRAIN: Assault003_x264 (50 fotos)
#  -> TRAIN: Assault004_x264 (50 fotos)
#  -> TRAIN: Assault005_x264 (39 fotos)
#  -> TRAIN: Assault006_x264 (50 fotos)
#  -> TRAIN: Assault007_x264 (38 fotos)
#  -> TRAIN: Assault008_x264 (50 fotos)
#  -> TRAIN: Assault009_x264 (50 fotos)
#  -> TRAIN: Assault010_x264 (50 fotos)
#  -> TRAIN: Assault011_x264 (45 fotos)
#  -> TRAIN: Assault012_x264 (14 fotos)
#  -> TRAIN: Assault013_x264 (28 fotos)
#  -> TRAIN: Assault014_x264 (21 fotos)
#  -> TRAIN: Assault015_x264 (38 fotos)
#  -> TRAIN: Assault016_x264 (50 fotos)
#  -> TRAIN: Assault017_x264 (8 fotos)
#  -> TRAIN: Assault018_x264 (3 fotos)
#  -> TRAIN: Assault019_x264 (42 fotos)
#  -> TRAIN: Assault020_x264 (9 fotos)
#  -> TRAIN: Assault022_x264 (35 fotos)
#  -> TRAIN: Assault023_x264 (11 fotos)
#  -> TRAIN: Assault024_x264 (14 fotos)
#  -> TRAIN: Assault025_x264 (29 fotos)
#  -> TRAIN: Assault026_x264 (16 fotos)
#  -> TRAIN: Assault027_x264 (50 fotos)
#  -> TRAIN: Assault028_x264 (13 fotos)
#  -> TRAIN: Assault029_x264 (19 fotos)
#  -> TRAIN: Assault030_x264 (50 fotos)
#  -> TRAIN: Assault031_x264 (19 fotos)
#  -> TRAIN: Assault032_x264 (13 fotos)
#  -> TRAIN: Assault033_x264 (37 fotos)
#  -> TRAIN: Assault034_x264 (33 fotos)
#  -> TRAIN: Assault035_x264 (26 fotos)
#  -> TRAIN: Assault036_x264 (27 fotos)
#  -> TRAIN: Assault037_x264 (50 fotos)
#  -> TRAIN: Assault038_x264 (4 fotos)
#  -> TRAIN: Assault039_x264 (9 fotos)
#  -> TRAIN: Assault040_x264 (1 fotos)
#  -> TRAIN: Assault041_x264 (50 fotos)
#  -> TEST: Assault042_x264 (3 fotos)
#  -> TEST: Assault044_x264 (25 fotos)
#  -> TEST: Assault045_x264 (21 fotos)
#  -> TEST: Assault046_x264 (24 fotos)
#  -> TEST: Assault047_x264 (2 fotos)
#  -> TEST: Assault048_x264 (50 fotos)
#  -> TEST: Assault049_x264 (28 fotos)
#  -> TEST: Assault050_x264 (12 fotos)
#  -> TEST: Assault051_x264 (19 fotos)
#  -> TEST: Assault052_x264 (26 fotos)

# %%
#Fotogramas videos carpeta "Assault"
procesar_lote_videos_split(
    ruta_carpeta=r"data\raw\Stealing",
    carpeta_base_destino="Asaltos",  # El nombre de la clase
    limite_videos=50,
    cada_n_frames=30,
    umbral=0.5,
    max_fotos_video=50)
# Out:
#  -> TRAIN: Stealing002_x264 (10 fotos)
#  -> TRAIN: Stealing003_x264 (0 fotos)
#  -> TRAIN: Stealing004_x264 (50 fotos)
#  -> TRAIN: Stealing006_x264 (50 fotos)
#  -> TRAIN: Stealing007_x264 (50 fotos)
#  -> TRAIN: Stealing008_x264 (19 fotos)
#  -> TRAIN: Stealing009_x264 (8 fotos)
#  -> TRAIN: Stealing010_x264 (50 fotos)
#  -> TRAIN: Stealing011_x264 (37 fotos)
#  -> TRAIN: Stealing012_x264 (39 fotos)
#  -> TRAIN: Stealing013_x264 (33 fotos)
#  -> TRAIN: Stealing014_x264 (50 fotos)
#  -> TRAIN: Stealing015_x264 (0 fotos)
#  -> TRAIN: Stealing016_x264 (1 fotos)
#  -> TRAIN: Stealing017_x264 (34 fotos)
#  -> TRAIN: Stealing018_x264 (5 fotos)
#  -> TRAIN: Stealing019_x264 (43 fotos)
#  -> TRAIN: Stealing020_x264 (50 fotos)
#  -> TRAIN: Stealing021_x264 (10 fotos)
#  -> TRAIN: Stealing022_x264 (50 fotos)
#  -> TRAIN: Stealing023_x264 (17 fotos)
#  -> TRAIN: Stealing024_x264 (19 fotos)
#  -> TRAIN: Stealing025_x264 (50 fotos)
#  -> TRAIN: Stealing026_x264 (4 fotos)
#  -> TRAIN: Stealing027_x264 (50 fotos)
#  -> TRAIN: Stealing028_x264 (18 fotos)
#  -> TRAIN: Stealing029_x264 (6 fotos)
#  -> TRAIN: Stealing030_x264 (17 fotos)
#  -> TRAIN: Stealing031_x264 (24 fotos)
#  -> TRAIN: Stealing032_x264 (50 fotos)
#  -> TRAIN: Stealing035_x264 (28 fotos)
#  -> TRAIN: Stealing036_x264 (33 fotos)
#  -> TRAIN: Stealing037_x264 (50 fotos)
#  -> TRAIN: Stealing042_x264 (7 fotos)
#  -> TRAIN: Stealing043_x264 (50 fotos)
#  -> TRAIN: Stealing044_x264 (19 fotos)
#  -> TRAIN: Stealing045_x264 (4 fotos)
#  -> TRAIN: Stealing046_x264 (35 fotos)
#  -> TRAIN: Stealing047_x264 (8 fotos)
#  -> TRAIN: Stealing048_x264 (50 fotos)
#  -> TEST: Stealing049_x264 (0 fotos)
#  -> TEST: Stealing050_x264 (0 fotos)
#  -> TEST: Stealing051_x264 (12 fotos)
#  -> TEST: Stealing052_x264 (44 fotos)
#  -> TEST: Stealing053_x264 (12 fotos)
#  -> TEST: Stealing054_x264 (21 fotos)
#  -> TEST: Stealing055_x264 (20 fotos)
#  -> TEST: Stealing057_x264 (48 fotos)
#  -> TEST: Stealing058_x264 (50 fotos)
#  -> TEST: Stealing059_x264 (12 fotos)

# %%
train_path = "../data/processed/train"
test_path = "../data/processed/test"

# %%
os.listdir(train_path)
# Out:
# ['Asaltos', 'Normal', 'Pelea', 'Vandalismo']

# %%
os.listdir(test_path)
# Out:
# ['Asaltos', 'Normal', 'Pelea', 'Vandalismo']

# %% [markdown]
# # 3.Preprocesado

# %% [markdown]
# ## 3.1Visualización de imágenes

# %%
os.listdir(train_path + '/Asaltos')[0]
# Out:
# 'Assault001_x264_f1050.jpg'

# %%
ruta_Asalto = train_path + '/Asaltos/' + os.listdir(train_path + '/Asaltos')[100] # os.listdir() crea una lista en este caso lista de las imagenes

# %%
imagen_Asalto= imread(ruta_Asalto)# imread() Su trabajo es abrir el archivo de imagen que se encuentra en la ruta especificada y "traducirlo".

# %%
plt.imshow(imagen_Asalto) #Mostrar la imagen

# %% [markdown]
# **Cantidad imágenes en la carpeta de entrenamiento**

# %%
len(os.listdir(train_path+'\\Normal'))
# Out:
# 1083

# %%
len(os.listdir(train_path+'\\Asaltos'))
# Out:
# 1711

# %%
len(os.listdir(train_path+'\\Pelea'))
# Out:
# 868

# %%
len(os.listdir(train_path+'\\Vandalismo'))
# Out:
# 1516

# %% [markdown]
# ## 3.2 Calcular dimensiones promedio

# %%
dim1_ddl = []
dim2_ddl = []
for fichero_imagen in os.listdir(train_path+'\\Normal'): #lista de todas las imagenes de la carpeta dandelion
    img = imread(train_path+'\\Normal'+'\\'+fichero_imagen) #Las "traduce"
    d1,d2,colors = img.shape #(Altura, Anchura, Canales)
    dim1_ddl.append(d1)
    dim2_ddl.append(d2)

# %%
sns.jointplot(x=dim1_ddl,y=dim2_ddl)

# %%
dim1_ddl = []
dim2_ddl = []
for fichero_imagen in os.listdir(train_path+'\\Asaltos'): #lista de todas las imagenes de la carpeta dandelion
    img = imread(train_path+'\\Asaltos'+'\\'+fichero_imagen) #Las "traduce"
    d1,d2,colors = img.shape #(Altura, Anchura, Canales)
    dim1_ddl.append(d1)
    dim2_ddl.append(d2)

# %%
sns.jointplot(x=dim1_ddl,y=dim2_ddl)

# %%
dim1_ddl = []
dim2_ddl = []
for fichero_imagen in os.listdir(train_path+'\\Pelea'): #lista de todas las imagenes de la carpeta dandelion
    img = imread(train_path+'\\Pelea'+'\\'+fichero_imagen) #Las "traduce"
    d1,d2,colors = img.shape #(Altura, Anchura, Canales)
    dim1_ddl.append(d1)
    dim2_ddl.append(d2)

# %%
sns.jointplot(x=dim1_ddl,y=dim2_ddl)

# %%
dim1_ddl = []
dim2_ddl = []
for fichero_imagen in os.listdir(train_path+'\\Vandalismo'): #lista de todas las imagenes de la carpeta dandelion
    img = imread(train_path+'\\Vandalismo'+'\\'+fichero_imagen) #Las "traduce"
    d1,d2,colors = img.shape #(Altura, Anchura, Canales)
    dim1_ddl.append(d1)
    dim2_ddl.append(d2)

# %%
sns.jointplot(x=dim1_ddl,y=dim2_ddl)

# %% [markdown]
# # 3.3 Manipulación de imágenes

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=20, # rotación máxima de 20º (depende del caso de uso)
                               width_shift_range=0.10, # Desplazamiento en la anchura máximo del -5% --- +5%
                               height_shift_range=0.10, # Desplazamiento en la altura máximo del -5% --- +5%
                               rescale=1/255, # Reescalar la imagen para normalizarla entre 0-1
                               shear_range=0.1, # Distorsión de la imagen a partir de un eje - persepectiva (max 10%)
                               zoom_range=0.1, # Zoom in máximo 10%
                               horizontal_flip=True,# Permitir giro horizontal de la imagen (espejo)
                               fill_mode='nearest' # Rellenar píxeles vacíos con el valor más cercano
                              )

# %%
plt.imshow(imagen_Asalto)

# %%
plt.imshow(image_gen.random_transform(imagen_Asalto)) # random_transform, Crea variaciones infinitas de las imágenes originales.

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 5178 images belonging to 4 classes.

# %%
image_gen.flow_from_directory(test_path)
# Out:
# Found 1508 images belonging to 4 classes.

# %%
batch_size = 16 #Definimos un batch_size en función de la RAM

# %%
image_shape = (240,320,3)

# %%
train_image_gen = image_gen.flow_from_directory(train_path,
                                               target_size=image_shape[:2], #image_shape = (240,320,3), target_size solo necesita anchura x altura
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='categorical') #binary si clasificación binaria
# Out:
# Found 5178 images belonging to 4 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_path,
                                               target_size=image_shape[:2], # image_shape = (250,335) no interesa el canal 3
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='categorical',shuffle=False) #En el conjunto de test no aplicamos shuffle para no "barajar" las imágenes
# Out:
# Found 1508 images belonging to 4 classes.

# %%
train_image_gen.class_indices
# Out:
# {'Asaltos': 0, 'Normal': 1, 'Pelea': 2, 'Vandalismo': 3}

# %% [markdown]
# # 4.Creación del Modelo

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %%
model = Sequential()

# CAPA CONVOLUCIONAL
model.add(Conv2D(filters=32, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

# CAPA CONVOLUCIONAL (más capas convolucionales conforme mayor complejidad del dataset de imágenes, aumentar progresivamente número de filtros en potencia de 2)
model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

# CAPA CONVOLUCIONAL (más capas convolucionales conforme mayor complejidad del dataset de imágenes, aumentar progresivamente número de filtros en potencia de 2)
model.add(Conv2D(filters=128, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

# CAPA FLATTEN: Convierte las imágenes de 250x335 en un array de 1 dimensión de 250x335 = 83750 valores antes de la capa final
model.add(Flatten())

# CAPA DENSE (Indicar neuronas potencia de 2, variable para optimizar modelo)
model.add(Dense(128))
model.add(Activation('relu'))

# CAPA DROPOUT (ayuda a reducir overfitting desactivando aleatoriamente neuronas durante el entrenamiento(epoc))
model.add(Dropout(0.6))

# CAPA FINAL DE CLASIFICACIÓN (4 posibles clases = 4 neuronas, si fuera problema binario utilizar 'sigmoid' y 1 neurona)
model.add(Dense(4, activation='softmax'))


from tensorflow.keras.optimizers import Adam
# Usa un valor 10 veces más pequeño aprende mas lento
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# C:\SmartCityIA\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 238, 318, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 119, 159, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 117, 157, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 58, 78, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 76, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 38, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 136192)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    17,432,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,526,468 (66.86 MB)
#  Trainable params: 17,526,468 (66.86 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 5.Entrenamiento del modelo

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=4,             # Dale un poco más de chance
    restore_best_weights=True, # ESTO ES VITAL: recupera el modelo de la Epoch 1 o 2
    verbose=1
)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.utils import class_weight
import numpy as np

# Obtiene las etiquetas de las clases del generador de entrenamiento
labels = train_image_gen.classes

# Calcula los pesos automáticamente basados en el support
weights = class_weight.compute_class_weight(
    class_weight='balanced', #Balancea los datos categorias con menos fotos les da un peso alto
    classes=np.unique(labels), #Identifica clases unicas
    y=labels
)

#Los convierte a un diccionario que Keras entienda
dict_class_weights = dict(enumerate(weights))

print("Pesos asignados por clase:", dict_class_weights)
# Out:
# Pesos asignados por clase: {0: np.float64(0.7565751022793687), 1: np.float64(1.1952908587257618), 2: np.float64(1.4913594470046083), 3: np.float64(0.853891820580475)}

# %%
results = model.fit(train_image_gen,
                              epochs=15,
                              validation_data=test_image_gen,
                              class_weight=dict_class_weights,
                              callbacks=[early_stop])
# Out:
# Epoch 1/35
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 499s 2s/step - accuracy: 0.3474 - loss: 1.3254 - val_accuracy: 0.3992 - val_loss: 1.3129
# Epoch 2/35
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 482s 1s/step - accuracy: 0.4679 - loss: 1.1616 - val_accuracy: 0.3767 - val_loss: 1.3500
# Epoch 3/35
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 529s 2s/step - accuracy: 0.5278 - loss: 1.0681 - val_accuracy: 0.4072 - val_loss: 1.3061
# Epoch 4/35
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 489s 2s/step - accuracy: 0.5684 - loss: 0.9940 - val_accuracy: 0.4052 - val_loss: 1.2867
# Epoch 5/35
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 482s 1s/step - accuracy: 0.6087 - loss: 0.9230 - val_accuracy: 0.4138 - val_loss: 1.3430
# Epoch 6/35
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 481s 1s/step - accuracy: 0.6549 - loss: 0.8309 - val_accuracy: 0.4410 - val_loss: 1.2755
# Epoch 7/35
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 481s 1s/step - accuracy: 0.6638 - loss: 0.8006 - val_accuracy: 0.4629 - val_loss: 1.2908
# Epoch 8/35
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 481s 1s/step - accuracy: 0.6798 - loss: 0.7614 - val_accuracy: 0.4682 - val_loss: 1.2923
# Epoch 9/35
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 481s 1s/step - accuracy: 0.7065 - loss: 0.7152 - val_accuracy: 0.4569 - val_loss: 1.3786
# Epoch 10/35
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 542s 2s/step - accuracy: 0.7202 - loss: 0.6862 - val_accuracy: 0.4211 - val_loss: 1.3647
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 6.

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses[['loss','val_loss']].plot()
# Out:
# <Axes: >

# %%
losses[['accuracy','val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # 6. Evaluación del modelo

# %% [markdown]
# ## 6.1 Predicción sobre el conjunto de Test

# %%
model.metrics_names
# Out:
# ['loss', 'compile_metrics']

# %%
pred_probabilities = model.predict(test_image_gen)
# Out:
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 52s 545ms/step

# %%
pred_probabilities #Probabilidad
# Out:
# array([[0.31536335, 0.13699928, 0.4797677 , 0.06786971],
#        [0.1965928 , 0.28650147, 0.45689836, 0.0600074 ],
#        [0.41914952, 0.10052642, 0.17339765, 0.3069264 ],
#        ...,
#        [0.6417793 , 0.292314  , 0.03800234, 0.02790439],
#        [0.18049291, 0.65531504, 0.15105219, 0.01313978],
#        [0.4160061 , 0.3721553 , 0.1967828 , 0.01505574]],
#       shape=(1508, 4), dtype=float32)

# %%
test_image_gen.classes #Respuestas correctas
# Out:
# array([0, 0, 0, ..., 3, 3, 3], shape=(1508,), dtype=int32)

# %%
# predictions = model.predict_classes(test_image_gen)
#Usar si la sale predict_classes como deprecated:
predictions = np.argmax(model.predict(test_image_gen), axis=-1)
# Out:
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 48s 502ms/step

# %%
predictions
# Out:
# array([2, 2, 3, ..., 1, 0, 1], shape=(1508,))

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(test_image_gen.classes,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.27      0.41      0.32       339
#            1       0.58      0.69      0.63       337
#            2       0.42      0.23      0.30       386
#            3       0.47      0.39      0.43       446
#
#     accuracy                           0.42      1508
#    macro avg       0.43      0.43      0.42      1508
# weighted avg       0.44      0.42      0.42      1508

# %%
confusion_matrix(test_image_gen.classes,predictions)
# Out:
# array([[140,  57,  19, 123],
#        [ 34, 231,  28,  44],
#        [226,  39,  90,  31],
#        [124,  69,  78, 175]])

# %%
plt.figure(figsize=(10,7))
sns.heatmap(confusion_matrix(test_image_gen.classes, predictions), annot=True, fmt='g')
# Out:
# <Axes: >
