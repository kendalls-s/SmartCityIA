# %% [markdown]
# # Asistente Inteligente para Seguridad Urbana en Costa Rica
# ### Módulos del Asistente Inteligente — CNN Detección en imágenes
# ### Módulo 1: Detección de actividad sospechosa en imágenes CCTV

# %%
import pandas as pd
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from CNN import procesar_lote_videos_split, vaciar_contenido
print("Funciona")
# Out:
# Funciona

# %%
vaciar_contenido()
# Out:
# Contenido eliminado de: train/Normal
# Contenido eliminado de: train/Asaltos
# Contenido eliminado de: train/Pelea
# Contenido eliminado de: train/Vandalismo
# Contenido eliminado de: test/Normal
# Contenido eliminado de: test/Asaltos
# Contenido eliminado de: test/Pelea
# Contenido eliminado de: test/Vandalismo

# %% [markdown]
# ## 1.Importación de librerias

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread

# %% [markdown]
# ## 2.Importación de fuentes de datos

# %%
ruta = r"..\data\raw\Normal-Videos-Part-1"
total_fotos = len(os.listdir(ruta))

print(f"Hay {total_fotos} videos en la carpeta ")
# Out:
# Hay 150 videos en la carpeta

# %%
ruta = r"..\data\raw\Fighting"
total_fotos = len(os.listdir(ruta))

print(f"Hay {total_fotos} videos en la carpeta ")
# Out:
# Hay 50 videos en la carpeta

# %%
ruta = r"..\data\raw\Assault"
total_fotos = len(os.listdir(ruta))

print(f"Hay {total_fotos} videos en la carpeta ")
# Out:
# Hay 50 videos en la carpeta

# %%
ruta = r"..\data\raw\Arson"
total_fotos = len(os.listdir(ruta))

print(f"Hay {total_fotos} videos en la carpeta ")
# Out:
# Hay 50 videos en la carpeta

# %%
ruta = r"..\data\raw\Vandalism"
total_fotos = len(os.listdir(ruta))

print(f"Hay {total_fotos} videos en la carpeta ")
# Out:
# Hay 50 videos en la carpeta

# %%
ruta = r"..\data\raw\Stealing"
total_fotos = len(os.listdir(ruta))

print(f"Hay {total_fotos} videos en la carpeta ")
# Out:
# Hay 100 videos en la carpeta

# %%
#Fotogramas videos carpeta "Normal-Videos-Part-1"
procesar_lote_videos_split(
    ruta_carpeta="data/raw/Normal-Videos-Part-1",
    carpeta_base_destino="Normal", # El nombre de la clase (destino)
    limite_videos=150,
    cada_n_frames=90,
    umbral=1.2,
    max_fotos_video=5000)
# Out:
#  -> TRAIN: Normal_Videos_003_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_006_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_010_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_014_x264 (3 fotos)
#  -> TRAIN: Normal_Videos_015_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_018_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_019_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_024_x264 (2 fotos)
#  -> TRAIN: Normal_Videos_025_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_027_x264 (1 fotos)
#  -> TRAIN: Normal_Videos_033_x264 (9 fotos)
#  -> TRAIN: Normal_Videos_034_x264 (4 fotos)
#  -> TRAIN: Normal_Videos_041_x264 (12 fotos)
#  -> TRAIN: Normal_Videos_042_x264 (19 fotos)
#  -> TRAIN: Normal_Videos_048_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_050_x264 (35 fotos)
#  -> TRAIN: Normal_Videos_051_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_056_x264 (0 fotos)
#  -> TRAIN: Normal_Videos_059_x264 (14 fotos)
#  -> TRAIN: Normal_Videos_063_x264 (1 fotos)
#  -> TRAIN: Normal_Videos_067_x264 (0 fotos)
# ...

# %%
#Fotogramas videos carpeta "Fighting"
procesar_lote_videos_split(
    ruta_carpeta=r"data\V\Fighting\Fighting",
    carpeta_base_destino="Pelea",  # El nombre de la clase (destino)
    limite_videos=30,
    cada_n_frames=10,
    umbral=1.0,
    max_fotos_video=5000)
# Out:
#  -> TRAIN: 1 (1 fotos)
#  -> TRAIN: 10 (5 fotos)
#  -> TRAIN: 11 (16 fotos)
#  -> TRAIN: 12 (1 fotos)
#  -> TRAIN: 13 (0 fotos)
#  -> TRAIN: 14 (74 fotos)
#  -> TRAIN: 15 (20 fotos)
#  -> TRAIN: 16 (0 fotos)
#  -> TRAIN: 18 (0 fotos)
#  -> TRAIN: 19 (124 fotos)
#  -> TRAIN: 2 (54 fotos)
#  -> TRAIN: 20 (38 fotos)
#  -> TRAIN: 24 (0 fotos)
#  -> TRAIN: 26 (6 fotos)
#  -> TRAIN: 3 (0 fotos)
#  -> TRAIN: 30 (0 fotos)
#  -> TRAIN: 31 (75 fotos)
#  -> TRAIN: 33 (39 fotos)
#  -> TRAIN: 34 (1 fotos)
#  -> TRAIN: 35 (3 fotos)
#  -> TRAIN: 37 (69 fotos)
#  -> TRAIN: 38 (28 fotos)
#  -> TRAIN: 4 (5 fotos)
#  -> TRAIN: 40 (121 fotos)
#  -> TEST: 43 (19 fotos)
#  -> TEST: 5 (19 fotos)
#  -> TEST: 6 (5 fotos)
#  -> TEST: 7 (6 fotos)
#  -> TEST: 8 (87 fotos)
#  -> TEST: 9 (35 fotos)

# %%
#Fotogramas videos carpeta "Arson"
procesar_lote_videos_split(
    ruta_carpeta=r"data\V\Vandalism\Vandalism",
    carpeta_base_destino="Vandalismo",  # El nombre de la clase (destino)
    limite_videos=48,
    cada_n_frames=10,
    umbral=1.0,
    max_fotos_video=5000)
# Out:
#  -> TRAIN: Vandalism001 (26 fotos)
#  -> TRAIN: Vandalism002 (42 fotos)
#  -> TRAIN: Vandalism003 (2 fotos)
#  -> TRAIN: Vandalism004 (2 fotos)
#  -> TRAIN: Vandalism005 (70 fotos)
#  -> TRAIN: Vandalism006 (9 fotos)
#  -> TRAIN: Vandalism007 (0 fotos)
#  -> TRAIN: Vandalism008 (4 fotos)
#  -> TRAIN: Vandalism009 (0 fotos)
#  -> TRAIN: Vandalism010 (2 fotos)
#  -> TRAIN: Vandalism011 (5 fotos)
#  -> TRAIN: Vandalism012 (0 fotos)
#  -> TRAIN: Vandalism013 (15 fotos)
#  -> TRAIN: Vandalism014 (4 fotos)
#  -> TRAIN: Vandalism015 (30 fotos)
#  -> TRAIN: Vandalism016 (6 fotos)
#  -> TRAIN: Vandalism017 (6 fotos)
#  -> TRAIN: Vandalism018 (0 fotos)
#  -> TRAIN: Vandalism019 (3 fotos)
#  -> TRAIN: Vandalism020 (3 fotos)
#  -> TRAIN: Vandalism021 (0 fotos)
#  -> TRAIN: Vandalism022 (0 fotos)
#  -> TRAIN: Vandalism023 (32 fotos)
#  -> TRAIN: Vandalism024 (21 fotos)
#  -> TRAIN: Vandalism025 (43 fotos)
#  -> TRAIN: Vandalism026 (0 fotos)
#  -> TRAIN: Vandalism027 (52 fotos)
# ...

# %%
#Fotogramas videos carpeta "Arson"
procesar_lote_videos_split(
    ruta_carpeta=r"data\raw\Arson",
    carpeta_base_destino="Vandalismo",  # El nombre de la clase (destino)
    limite_videos=50,
    cada_n_frames=10,
    umbral=0.6,
    max_fotos_video=5000)
# Out:
#  -> TRAIN: Arson001_x264 (25 fotos)
#  -> TRAIN: Arson002_x264 (76 fotos)
#  -> TRAIN: Arson003_x264 (74 fotos)
#  -> TRAIN: Arson005_x264 (61 fotos)
#  -> TRAIN: Arson006_x264 (60 fotos)
#  -> TRAIN: Arson007_x264 (4 fotos)
#  -> TRAIN: Arson008_x264 (35 fotos)
#  -> TRAIN: Arson009_x264 (63 fotos)
#  -> TRAIN: Arson010_x264 (26 fotos)
#  -> TRAIN: Arson011_x264 (105 fotos)
#  -> TRAIN: Arson012_x264 (25 fotos)
#  -> TRAIN: Arson013_x264 (30 fotos)
#  -> TRAIN: Arson014_x264 (41 fotos)
#  -> TRAIN: Arson015_x264 (618 fotos)
#  -> TRAIN: Arson016_x264 (43 fotos)
#  -> TRAIN: Arson017_x264 (23 fotos)
#  -> TRAIN: Arson018_x264 (26 fotos)
#  -> TRAIN: Arson019_x264 (752 fotos)
#  -> TRAIN: Arson020_x264 (44 fotos)
#  -> TRAIN: Arson021_x264 (13 fotos)
#  -> TRAIN: Arson022_x264 (49 fotos)
#  -> TRAIN: Arson023_x264 (51 fotos)
#  -> TRAIN: Arson024_x264 (188 fotos)
#  -> TRAIN: Arson025_x264 (85 fotos)
#  -> TRAIN: Arson026_x264 (260 fotos)
#  -> TRAIN: Arson027_x264 (44 fotos)
# ...

# %%
#Fotogramas videos carpeta "Assault"
procesar_lote_videos_split(
    ruta_carpeta=r"data\raw\Assault",
    carpeta_base_destino="Asaltos",  # El nombre de la clase (destino)
    limite_videos=50,
    cada_n_frames=10,
    umbral=0.5,
    max_fotos_video=5000)
# Out:
#  -> TRAIN: Assault001_x264 (50 fotos)
#  -> TRAIN: Assault002_x264 (50 fotos)
#  -> TRAIN: Assault003_x264 (50 fotos)
#  -> TRAIN: Assault004_x264 (50 fotos)
#  -> TRAIN: Assault005_x264 (39 fotos)
#  -> TRAIN: Assault006_x264 (50 fotos)
#  -> TRAIN: Assault007_x264 (38 fotos)
#  -> TRAIN: Assault008_x264 (50 fotos)
#  -> TRAIN: Assault009_x264 (50 fotos)
#  -> TRAIN: Assault010_x264 (50 fotos)
#  -> TRAIN: Assault011_x264 (45 fotos)
#  -> TRAIN: Assault012_x264 (14 fotos)
#  -> TRAIN: Assault013_x264 (28 fotos)
#  -> TRAIN: Assault014_x264 (21 fotos)
#  -> TRAIN: Assault015_x264 (38 fotos)
#  -> TRAIN: Assault016_x264 (50 fotos)
#  -> TRAIN: Assault017_x264 (8 fotos)
#  -> TRAIN: Assault018_x264 (3 fotos)
#  -> TRAIN: Assault019_x264 (42 fotos)
#  -> TRAIN: Assault020_x264 (9 fotos)
#  -> TRAIN: Assault022_x264 (35 fotos)
#  -> TRAIN: Assault023_x264 (11 fotos)
#  -> TRAIN: Assault024_x264 (14 fotos)
#  -> TRAIN: Assault025_x264 (29 fotos)
#  -> TRAIN: Assault026_x264 (16 fotos)
# ...

# %%
#Fotogramas videos carpeta "Assault"
procesar_lote_videos_split(
    ruta_carpeta=r"data\V\Stealing\Stealing",
    carpeta_base_destino="Asaltos",  # El nombre de la clase
    limite_videos=44,
    cada_n_frames=5,
    umbral=1.0,
    max_fotos_video=5000)
# Out:
#  -> TRAIN: stealing001 (0 fotos)
#  -> TRAIN: stealing002 (29 fotos)
#  -> TRAIN: stealing003 (103 fotos)
#  -> TRAIN: stealing004 (0 fotos)
#  -> TRAIN: stealing005 (41 fotos)
#  -> TRAIN: stealing006 (1 fotos)
#  -> TRAIN: stealing007 (0 fotos)
#  -> TRAIN: stealing008 (1 fotos)
#  -> TRAIN: stealing009 (50 fotos)
#  -> TRAIN: stealing010 (1 fotos)
#  -> TRAIN: stealing011 (13 fotos)
#  -> TRAIN: stealing012 (0 fotos)
#  -> TRAIN: stealing013 (22 fotos)
#  -> TRAIN: stealing014 (6 fotos)
#  -> TRAIN: stealing015 (6 fotos)
#  -> TRAIN: stealing016 (2 fotos)
#  -> TRAIN: stealing017 (44 fotos)
#  -> TRAIN: stealing018 (19 fotos)
#  -> TRAIN: stealing019 (7 fotos)
#  -> TRAIN: stealing020 (30 fotos)
#  -> TRAIN: stealing021 (0 fotos)
#  -> TRAIN: stealing022 (12 fotos)
#  -> TRAIN: stealing023 (17 fotos)
#  -> TRAIN: stealing024 (1 fotos)
#  -> TRAIN: stealing025 (5 fotos)
#  -> TRAIN: stealing026 (11 fotos)
#  -> TRAIN: stealing027 (10 fotos)
#  -> TRAIN: stealing028 (0 fotos)
# ...

# %%
train_path = "../data/processed/train"
test_path = "../data/processed/test"

# %%
os.listdir(train_path)
# Out:
# ['Asaltos', 'Normal', 'Pelea', 'Vandalismo']

# %%
os.listdir(test_path)
# Out:
# ['Asaltos', 'Normal', 'Pelea', 'Vandalismo']

# %% [markdown]
# # 3.Preprocesado

# %% [markdown]
# ## 3.1Visualización de imágenes

# %%
os.listdir(train_path + '/Asaltos')[0]
# Out:
# 'stealing002_f175.jpg'

# %%
ruta_Asalto = train_path + '/Asaltos/' + os.listdir(train_path + '/Asaltos')[100] # os.listdir() crea una lista en este caso lista de las imagenes

# %%
imagen_Asalto= imread(ruta_Asalto)# imread() Su trabajo es abrir el archivo de imagen que se encuentra en la ruta especificada y "traducirlo".

# %%
plt.imshow(imagen_Asalto) #Mostrar la imagen

# %% [markdown]
# **Cantidad imágenes en la carpeta de entrenamiento**

# %%
len(os.listdir(train_path+'\\Normal'))
# Out:
# 536

# %%
len(os.listdir(train_path+'\\Asaltos'))
# Out:
# 519

# %%
len(os.listdir(train_path+'\\Pelea'))
# Out:
# 680

# %%
len(os.listdir(train_path+'\\Vandalismo'))
# Out:
# 512

# %% [markdown]
# ## 3.2 Calcular dimensiones promedio

# %%
dim1_ddl = []
dim2_ddl = []
for fichero_imagen in os.listdir(train_path+'\\Normal'): #lista de todas las imagenes de la carpeta Normal
    img = imread(train_path+'\\Normal'+'\\'+fichero_imagen) #Las "traduce"
    d1,d2,colors = img.shape #(Altura, Anchura, Canales)
    dim1_ddl.append(d1)
    dim2_ddl.append(d2)

# %%
sns.jointplot(x=dim1_ddl,y=dim2_ddl)

# %%
dim1_ddl = []
dim2_ddl = []
for fichero_imagen in os.listdir(train_path+'\\Asaltos'): #lista de todas las imagenes de la carpeta asaltas / robo
    img = imread(train_path+'\\Asaltos'+'\\'+fichero_imagen) #Las "traduce"
    d1,d2,colors = img.shape #(Altura, Anchura, Canales)
    dim1_ddl.append(d1)
    dim2_ddl.append(d2)

# %%
sns.jointplot(x=dim1_ddl,y=dim2_ddl)

# %%
dim1_ddl = []
dim2_ddl = []
for fichero_imagen in os.listdir(train_path+'\\Pelea'): #lista de todas las imagenes de la carpeta pelea
    img = imread(train_path+'\\Pelea'+'\\'+fichero_imagen) #Las "traduce"
    d1,d2,colors = img.shape #(Altura, Anchura, Canales)
    dim1_ddl.append(d1)
    dim2_ddl.append(d2)

# %%
sns.jointplot(x=dim1_ddl,y=dim2_ddl)

# %%
dim1_ddl = []
dim2_ddl = []
for fichero_imagen in os.listdir(train_path+'\\Vandalismo'): #lista de todas las imagenes de la carpeta vandalismo
    img = imread(train_path+'\\Vandalismo'+'\\'+fichero_imagen) #Las "traduce"
    d1,d2,colors = img.shape #(Altura, Anchura, Canales)
    dim1_ddl.append(d1)
    dim2_ddl.append(d2)

# %%
sns.jointplot(x=dim1_ddl,y=dim2_ddl)

# %%
imagen_Asalto.shape
# Out:
# (720, 960, 3)

# %%
#Calcular resto categorías
dim1_asalto = []
dim2_asalto = []
for fichero_imagen in os.listdir(train_path+'\\Asaltos'):

    img = imread(train_path+'\\Asaltos'+'\\'+fichero_imagen)
    d1,d2,colors = img.shape
    dim1_asalto.append(d1)
    dim2_asalto.append(d2)

dim1_normal = []
dim2_normal = []
for fichero_imagen in os.listdir(train_path+'\\Normal'):

    img = imread(train_path+'\\Normal'+'\\'+fichero_imagen)
    d1,d2,colors = img.shape
    dim1_normal.append(d1)
    dim2_normal.append(d2)

dim1_pelea = []
dim2_pelea = []
for fichero_imagen in os.listdir(train_path+'\\Pelea'):

    img = imread(train_path+'\\Pelea'+'\\'+fichero_imagen)
    d1,d2,colors = img.shape
    dim1_pelea.append(d1)
    dim2_pelea.append(d2)

dim1_vandalismo = []
dim2_vandalismo = []
for fichero_imagen in os.listdir(train_path+'\\Vandalismo'):

    img = imread(train_path+'\\Vandalismo'+'\\'+fichero_imagen)
    d1,d2,colors = img.shape
    dim1_vandalismo.append(d1)
    dim2_vandalismo.append(d2)

# %%
np.mean(dim1_asalto + dim1_normal + dim1_pelea + dim1_vandalismo )
# Out:
# np.float64(714.4459279038718)

# %%
np.mean(dim2_asalto + dim2_normal + dim2_pelea + dim2_vandalismo )
# Out:
# np.float64(1097.8549176680017)

# %% [markdown]
# # 3.3 Manipulación de imágenes

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=20, # rotación máxima de 20º (depende del caso de uso)
                               width_shift_range=0.10, # Desplazamiento en la anchura máximo del -5% --- +5%
                               height_shift_range=0.10, # Desplazamiento en la altura máximo del -5% --- +5%
                               rescale=1/255, # Reescalar la imagen para normalizarla entre 0-1
                               shear_range=0.1, # Distorsión de la imagen a partir de un eje - persepectiva (max 10%)
                               zoom_range=0.1, # Zoom in máximo 10%
                               horizontal_flip=True,# Permitir giro horizontal de la imagen (espejo)
                               fill_mode='nearest' # Rellenar píxeles vacíos con el valor más cercano
                              )

# %%
plt.imshow(imagen_Asalto)

# %%
plt.imshow(image_gen.random_transform(imagen_Asalto)) # random_transform, Crea variaciones infinitas de las imágenes originales.

# %%
image_gen.flow_from_directory(train_path) # Aplicacion de la manipulacion de imaganes a el train
# Out:
# Found 2247 images belonging to 4 classes.

# %%
image_gen.flow_from_directory(test_path) # Aplicacion de la manipulacion de imaganes a el test
# Out:
# Found 1072 images belonging to 4 classes.

# %%
batch_size = 16 #Definimos un batch_size en función de la RAM

# %%
image_shape = (300,300,3)

# %%
train_image_gen = image_gen.flow_from_directory(train_path,
                                               target_size=image_shape[:2], #image_shape = (240,320,3 ejemplo), target_size solo necesita anchura x altura
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='categorical') #binary si clasificación binaria
# Out:
# Found 2247 images belonging to 4 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_path,
                                               target_size=image_shape[:2], # image_shape = (250,335) no interesa el canal 3
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='categorical',shuffle=False) #En el conjunto de test no aplicamos shuffle para no "barajar" las imágenes
# Out:
# Found 1072 images belonging to 4 classes.

# %%
train_image_gen.class_indices #Nuestras categorias
# Out:
# {'Asaltos': 0, 'Normal': 1, 'Pelea': 2, 'Vandalismo': 3}

# %% [markdown]
# # 4.Creación del Modelo

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %%
model = Sequential()

# CAPA CONVOLUCIONAL
model.add(Conv2D(filters=32, kernel_size=(3,3),input_shape=image_shape, activation='relu',)) # Lupa
model.add(MaxPooling2D(pool_size=(2, 2)))

# CAPA CONVOLUCIONAL (más capas convolucionales conforme mayor complejidad del dataset de imágenes, aumentar progresivamente número de filtros en potencia de 2)
model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

# CAPA CONVOLUCIONAL (más capas convolucionales conforme mayor complejidad del dataset de imágenes, aumentar progresivamente número de filtros en potencia de 2)
model.add(Conv2D(filters=128, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2))) #Division tamaño 2x2

# CAPA FLATTEN: Convierte las imágenes de 250x335 en un array de 1 dimensión de 250x335 = 83750 valores antes de la capa final
model.add(Flatten())

# CAPA DENSE (Indicar neuronas potencia de 2, variable para optimizar modelo)
model.add(Dense(256)) #Capas conectadas
model.add(Activation('relu'))

# CAPA DROPOUT (ayuda a reducir overfitting desactivando aleatoriamente neuronas durante el entrenamiento(epoc))
model.add(Dropout(0.5))

# CAPA FINAL DE CLASIFICACIÓN (4 posibles clases = 4 neuronas, si fuera problema binario utilizar 'sigmoid' y 1 neurona)
model.add(Dense(4, activation='softmax'))


from tensorflow.keras.optimizers import Adam
# Aprendizaje mas lento
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy', # Compara la predicción de la IA con la etiqueta real
              metrics=['accuracy'])
# Out:
# C:\SmartCityIA\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 298, 298, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 149, 149, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 147, 147, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 73, 73, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 71, 71, 128)    │        73,856 │
# ...

# %% [markdown]
# # 5.Entrenamiento del modelo

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=2)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
results = model.fit(train_image_gen,
                              epochs=15,
                              validation_data=test_image_gen,
                              callbacks=[early_stop])
# Out:
# Epoch 1/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 279s 2s/step - accuracy: 0.6084 - loss: 0.9110 - val_accuracy: 0.7547 - val_loss: 0.6628
# Epoch 2/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 286s 2s/step - accuracy: 0.7739 - loss: 0.5771 - val_accuracy: 0.8246 - val_loss: 0.4487
# Epoch 3/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 284s 2s/step - accuracy: 0.8238 - loss: 0.4756 - val_accuracy: 0.7910 - val_loss: 0.5161
# Epoch 4/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 283s 2s/step - accuracy: 0.8344 - loss: 0.4226 - val_accuracy: 0.8246 - val_loss: 0.4252
# Epoch 5/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 282s 2s/step - accuracy: 0.8594 - loss: 0.3808 - val_accuracy: 0.7444 - val_loss: 0.5940
# Epoch 6/15
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 278s 2s/step - accuracy: 0.8807 - loss: 0.3255 - val_accuracy: 0.7826 - val_loss: 0.5279

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses[['loss','val_loss']].plot()
# Out:
# <Axes: >

# %%
losses[['accuracy','val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # 6. Evaluación del modelo

# %% [markdown]
# ## 6.1 Predicción sobre el conjunto de Test

# %%
model.metrics_names
# Out:
# ['loss', 'compile_metrics']

# %%
pred_probabilities = model.predict(test_image_gen)
# Out:
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 40s 594ms/step

# %%
pred_probabilities #Probabilidad
# Out:
# array([[5.2610433e-01, 1.3715635e-01, 3.8165699e-03, 3.3292279e-01],
#        [9.5786279e-01, 1.7556102e-03, 5.2084372e-04, 3.9860763e-02],
#        [3.9604649e-01, 1.5207496e-01, 1.7974901e-03, 4.5008111e-01],
#        ...,
#        [5.2273148e-01, 1.2377383e-03, 8.9354039e-04, 4.7513723e-01],
#        [1.5619214e-01, 7.0752126e-01, 1.1653571e-03, 1.3512124e-01],
#        [7.5574428e-01, 3.9761286e-02, 3.1367113e-04, 2.0418072e-01]],
#       shape=(1072, 4), dtype=float32)

# %%
test_image_gen.classes #Respuestas correctas
# Out:
# array([0, 0, 0, ..., 3, 3, 3], shape=(1072,), dtype=int32)

# %%
# predictions = model.predict_classes(test_image_gen)
#Usar si la sale predict_classes como deprecated:
predictions = np.argmax(model.predict(test_image_gen), axis=-1)
# Out:
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 42s 620ms/step

# %%
predictions
# Out:
# array([0, 0, 0, ..., 3, 3, 3], shape=(1072,))

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(test_image_gen.classes,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.35      0.39       147
#            1       0.87      0.98      0.92       573
#            2       0.86      0.97      0.91       171
#            3       0.66      0.44      0.53       181
#
#     accuracy                           0.80      1072
#    macro avg       0.71      0.68      0.69      1072
# weighted avg       0.78      0.80      0.78      1072

# %%
confusion_matrix(test_image_gen.classes,predictions)
# Out:
# array([[ 51,  58,   2,  36],
#        [ 12, 561,   0,   0],
#        [  0,   0, 166,   5],
#        [ 49,  26,  26,  80]])

# %%
plt.figure(figsize=(10,7))
sns.heatmap(confusion_matrix(test_image_gen.classes, predictions), annot=True, fmt='g')
# Out:
# <Axes: >
